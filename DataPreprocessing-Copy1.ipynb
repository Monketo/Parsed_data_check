# %%
#from Vocabscraper import VocabularyScraper
import os
import pickle
import pandas
from copy import deepcopy
from collections import Counter
import re
import nltk
from  nltk.tokenize import word_tokenize as tokenizer
import itertools
import string
import numpy as np
from nltk import ngrams
import tensorflow as tf
import time
import csv
from tensorflow.contrib.tensorboard.plugins import projector

# %%
def load_data(preprocessed=False):
    
    ''' Helper function to load dataset '''
    data=None
    FILE_PATH= "words.pkl"
    if not os.path.exists(FILE_PATH):
        cursor = VocabularyScraper(None).db_executer
        cursor.execute("SELECT term,definitions,examples FROM terms")
        data = cursor.fetchall()
        with open(FILE_PATH,"wb") as file:
            pickle.dump(data,file)
    else:
        with open(FILE_PATH,"rb") as file:
            data = pickle.load(file)
    return data

# %%
def look_up_word(term,data):
    '''Name of the function is self-explanatory '''
        
    for word in data:
        if word[0]==term:
            return word
    return None

# %%
def find_optimum_length(defs_exs,percentiles):
    
    '''Name of the function is self-explanatory '''
    
    stats = [len(ex) for ex in defs_exs]
    df= pandas.DataFrame(stats,columns=["length of samples"])
    return df.describe(percentiles=percentiles)

# %%
def hasNumbers(inputString):
    return any(char.isdigit() for char in inputString)

# %%
def ex_remove_red_chars(*examples):
    
    ''' Function to remove redundant chars , like punctuation or part of speech markers
        Then to split them using "#$" or "&#" delimiters'''
    
    result=[]
    for example in examples:
        if example is not None:
            punctuation=re.sub("[#$&]*","",string.punctuation)
            punctuation = [char for char in punctuation]
            del_patterns = ["&[\w]+&",'”',"^[\s]","“","adj\n","v\n","n\n","adv\n",]
            del_patterns.extend(punctuation)
            for pattern in del_patterns:
                example = example.replace(pattern,"")
            example = example.replace("—"," ")
            example = example.lower()
            example = re.split(r"[&#$]*;*",example) 
            
            result.append(example)
        else:
            result.append("")
    return tuple(result)

# %%
def process_duplicates(data):
    ''' Function to avoid storing unneccessary duplicates'''
    
    terms= set()
    defs_exs=set()
   
    
    for word in data:
        terms.add(word[0])
        definitions,examples = word[1],word[2]
        definitions,examples =  ex_remove_red_chars(definitions,examples)
        defs_exs.update(definitions,examples)
        
    return(terms,defs_exs)

# %%
words=load_data()

# %%
look_up_word("word",words)
# Out:
# ('word',
#  'A word is a unit of language that native speakers can agree upon as a separate and distinct unit of meaning. Languages are made up of words. You must like words since you are here, on this word site. &$ If you say "What`s the good word?" you’re not actually asking for a word — you’re asking, "How are you?" or "What`s doing?" But if you ask "What`s the word on that restaurant?" you`re asking for an opinion. You can also "give your word," but that means that you`re promising something; you`re giving an oath. If your friend asks what you think of his girlfriend, you may want to word your response carefully — to watch your words. &$ n\na unit of language that native speakers can identify &$ n\na brief statement &$ n\na verbal command for action &$ n\nan exchange of views on some topic &$ n\na promise &$ n\na secret word or phrase known only to a restricted group &$ n\ninformation about recent and important events &$ n\na word is a string of bits stored in computer memory &$ v\nput into words or an expression &$ n\nthe divine word of God; the second person in the Trinity (incarnate in Jesus) &$ n\nthe sacred writings of the Christian religions &$ To say or write (something) using particular words &$ verbal contention; dispute &$ to flatter with words; to cajole &$ a brief statement &$ A finite string which is not a command or operator &$ Something which has been said; a comment, utterance; speech &$ account; tidings; message; communication; information; -- used only in the singular &$ a promise &$ A brief discussion or conversation &$ A distinct unit  of language (sounds in speech or written letters) with a particular meaning, composed of one or more morphemes, and also of one or more phonemes that determine its sound pattern &$ A fixed-size group of bits handled as a unit by a machine. On many 16-bit machines a word is 16 bits or two bytes &$ to express in words; to phrase &$ information about recent and important events &$ the sacred writings of the Christian religions &$ The creative word of God; logos &$ to ply with words; also, to cause to be by the use of a word or words &$ language considered as implying the faith or authority of the person who utters it; statement; affirmation; declaration; promise &$ The fact or action of speaking, as opposed to writing or to action &$ talk; discourse; speech; language &$ Different symbols, written or spoken, arranged together in a unique sequence that approximates a thought in a person\'s mind &$ put into words or an expression &$ Communication from god; the message of the Christian gospel; the Bible &$ An abbreviated form of word up; a statement of the acknowledgment of fact with a hint of nonchalant approval &$ a word is a string of bits stored in computer memory &$ An order; a request or instruction &$ the spoken sign of a conception or an idea; an articulate or vocal sound, or a combination of articulate and vocal sounds, uttered by the human voice, and by custom expressing an idea or ideas; a single component part of human speech or language; a constituent part of a sentence; a term; a vocable &$ A promise; an oath or guarantee &$ A group element, expressed as a product of group elements &$ Christ &$ a secret word or phrase known only to a restricted group &$ the divine word of God; the second person in the Trinity (incarnate in Jesus &$ a brief remark or observation; an expression; a phrase, clause, or short sentence &$ Scripture; The Bible &$ signal; order; command; direction &$ A distinct unit of language which is approved by some authority &$ a unit of language that native speakers can identify &$ A unit of text equivalent to five characters and one space &$ to use words, as in discussion; to argue; to dispute &$ Angry debate or conversation; argument &$ Any sequence of letters or characters considered as a discrete entity &$ an exchange of views on some topic &$ truth, to tell or speak the truth; the shortened form of the statement, "My word is my bond," an expression eventual ...
#  '&NNS& “words are the blocks from which sentences are made” &$ &NNS& “he hardly said ten words all morning” &$ &NN& “he didn`t say a word about it” &$ &NN& “when I give the word, charge!” &$ &NN& “we had a word or two about it” &$ &NN& “he gave his word” &$ &NNS& “large computers use words up to 64 bits long” &$ &NNP& “he went to carry the Word to the heathen”')

# %%
terms , defs_exs = process_duplicates(words)
# Out:
# /Users/mac/anaconda3/lib/python3.5/re.py:203: FutureWarning: split() requires a non-empty pattern match.
#   return _compile(pattern, flags).split(string, maxsplit)

# %%
def create_lookup_dicts(terms,defs_and_exs,threshhold_min,threshhold_max):
    
    ''' Function to create helping dictionaries for future word-to-integers (or conversely) conversion'''
    
    all_text = list(itertools.chain(*[sent.split() for sent in list(defs_exs)]))
    counter=Counter(all_text)

    index=0
    word_to_index=dict()
    
    
    
    for key,indx in counter.items():
        if not hasNumbers(key):
            if indx>threshhold_min and indx<threshhold_max:    
                word_to_index[key]=index
                index+=1
        
    #Terms should be treated differently,avoiding split,that's why we add them seperately
    
    for word in terms:
        if word not in word_to_index:
            word_to_index[word]=index
            index+=1
            
    index_to_word=dict()
    
    for key,index in word_to_index.items():
        index_to_word[index]=key
    return (word_to_index,index_to_word)

# %%
hasNumbers("c12h8nh")
# Out:
# True

# %%
word_to_index,index_to_word=create_lookup_dicts(terms,defs_exs,1,100000)

# %%
def encode(defs_exs,word2int,unknown_int=-2):
    '''Function to encode words to integers'''
    sentences=[]
    for example in defs_exs:
        sentence=[]
        for word in example.split():
            try:
                sentence.append(word2int[word])
            except KeyError:
                sentence.append(unknown_int)
        sentences.append(sentence) 
    encoded=np.array(sentences)
    return encoded

# %%
encoded=encode(defs_exs,word_to_index)

# %%
encoded
# Out:
# array([list([]), list([137662, 52326, -2, 82799, -2, 41095]),
#        list([137662, 28923, 137662, 79590]), ...,
#        list([242243, 64282, 320712, 242243, 4484, 30993, 21785, 242243, 13371, 320712, 27606, 54956, 137662, 16080, 4315]),
#        list([38405, 31993, -2, 152005, 8850, 46304]),
#        list([5040, 137662, 242243, 13371, -2, 74011, 85020, 41739, 24709])], dtype=object)

# %%
def skipgrams(sequence, n, k):
    ''' Can be deleted , was used for testing'''
    for ngram in ngrams(sequence, n + k, pad_right=True):
        head = ngram[:1]
        tail = ngram[1:]
        for skip_tail in itertools.combinations(tail, n - 1):
            if skip_tail[-1] is None:
                continue
            yield head + skip_tail

# %%
word_to_index
# Out:
# {'': 87561,
#  'howard': 3,
#  'unsugary': 87567,
#  'dickensian': 32810,
#  'membranophone': 87570,
#  'chemical-formula': 87571,
#  'splinters': 6,
#  'prohibitively': 87574,
#  'situation': 9,
#  'congestive heart failure': 87575,
#  'come the acid': 87578,
#  'cognitive neuroscientist': 262798,
#  'eft': 11,
#  'shoed': 13,
#  'metronomy': 87582,
#  'ceibhfhionn': 87584,
#  'affrontery': 87585,
#  'lozenged': 174874,
#  'spatting': 55069,
#  'tautophony': 87596,
#  'blackfoot daisy': 87597,
#  'fronted': 49789,
#  'ideogrammatic': 87600,
#  'picot': 87602,
#  'hem and haw': 87604,
#  'Nuclear Regulatory Commission': 87606,
#  'unbranded': 26,
#  'two-dimensionality': 340120,
#  'brass monkey': 87608,
#  'tabloidize': 87569,
#  'niddah': 87610,
#  'dictyopterous insect': 87611,
#  'unattempted': 87615,
#  'Curietherapy': 313625,
#  'microsurgically': 87617,
#  'chuiwan': 87619,
#  'postfactum': 87621,
#  'tetradecanoic': 72447,
#  'nonhuman': 36,
#  'roundbottomed': 37,
#  'eutectic mixture': 87624,
#  'briartite': 87626,
#  'Kendall rank correlation': 87627,
#  'Salix amygdaloides': 87633,
#  'visual space': 87635,
#  'halocyclization': 87638,
#  'crack wise': 91281,
#  'no-op': 87640,
#  'bill': 43,
#  'sushi bar': 262807,
#  'berdash': 87646,
#  'bled': 57,
#  'dissimulour': 87654,
#  'dont look a gift horse in the mouth': 87655,
#  'cats whiskers': 260322,
#  'peer group': 87657,
#  'bitbucket': 87659,
#  'Wystan Hugh Auden': 87660,
#  'art movement': 87661,
#  'biphenylene': 87667,
#  'longeron': 87669,
#  'nonbranched': 87670,
#  'molinillo': 87672,
#  'partial breach': 87675,
#  'genus Pimenta': 87676,
#  'psoralen': 69,
#  'unscrupulously': 70,
#  'malaysian': 71,
#  'Moore': 174888,
#  'cataplasia': 72,
#  'electroluminescent': 87679,
#  'lunch meeting': 262815,
#  'kozani': 87680,
#  'besoul': 87681,
#  'arabs': 76,
#  'chlorofucin': 87684,
#  'retarded': 59521,
#  'formulated': 79,
#  'double cross': 87690,
#  'russenorsk': 87693,
#  'cynarrhodium': 87692,
#  'pantie': 87694,
#  'dandelion': 85,
#  'calfflesh': 87700,
#  'groupers': 88,
#  'shocking pink': 87587,
#  'dinner dress': 87705,
#  'englobe': 87706,
#  'confounded': 28962,
#  'anythingarianism': 87707,
#  'nonperformance': 92,
#  'unipotently': 87710,
#  'Leyte': 122065,
#  'tripura': 96,
#  'flexoelectricity': 87714,
#  'debauchee': 100,
#  'desertification': 102,
#  'rewash': 262823,
#  'dedendum': 87721,
#  'spue': 87723,
#  'equipollent': 87725,
#  'brainish': 87727,
#  'despondency': 104,
#  'wistfully': 106,
#  'chaps': 107,
#  'vaccaria': 87731,
#  'legalizer': 87732,
#  'dethronize': 87733,
#  'paranoid personality disorder': 87737,
#  'cauldron': 111,
#  'jenkins': 730,
#  'real estate agent': 87744,
#  'minor diatonic scale': 87746,
#  'mixotrophy': 28967,
#  'quinolyl': 87747,
#  'formulating': 119,
#  'disendow': 87754,
#  'thickheaded': 121,
#  'enmuffle': 87753,
#  'pontoon bridge': 87758,
#  'raspberry tart': 87763,
#  'terrain park': 87764,
#  'wrong-timed': 87766,
#  'alacranite': 87768,
#  'aborad': 87771,
#  'Telopea speciosissima': 87773,
#  'newspaper advertisement': 87774,
#  'instrumental music': 87775,
#  'nonintellectual': 87776,
#  'valueless': 135,
#  'zworykin': 137,
#  'invigilate': 138,
#  'cytocompatibility': 229412,
#  'Galilean telescope': 87781,
#  'nonlethal': 903,
#  'foofooraw': 87785,
#  'circumferences': 30677,
#  'noncontractor': 87601,
#  'caden': 87787,
#  'genus Mya': 87790,
#  'medium-chain triglyceride': 87791,
#  'water wheel': 87795,
#  'tipsiness': 87797,
#  'Ictalurus punctatus': 87798,
#  'homocysteine': 148,
#  'tankard': 241654,
#  'toffy': 87809,
#  'winston': 28973,
#  'colon cancer': 87812,
#  'willet': 1023,
#  'Azores': 87814,
#  'chuffily': 174915,
#  'omnivores': 1031,
#  'pershing': 1035,
#  'kachina': 1059,
#  'clinocephaly': 87820,
#  'set-off': 87821,
#  'new york reload': 87823,
#  'phosphoenolpyruvate': 87824,
#  'central trait': 87825,
#  'awesomenessness': 87826,
#  'polytechnic institute': 87829,
#  'coextend': 87609,
#  'vireonidae': 58329,
#  'high-vitamin diet': 87832,
#  'capital of Vietnam': 87833,
#  'acetochlor': 87834,
#  'Burk': 87835,
#  'merak': 1110,
#  'jibboom': 87836,
#  'chambermaid': 168,
#  'attributive': 28975,
#  'fetiparous': 87837,
#  'scutellated': 172,
#  'benzenediamine': 262847,
#  'aesthetic emotion': 87841,
#  'chow mein': 87842,
#  'chirotopic': 87844,
#  'orfe': 87847,
#  'lithium hydroxide': 87845,
#  'rough-skinned newt': 174923,
#  'azygos': 178,
#  'acylglycerophosphoethanolamine': 87848,
#  'territoriality': 180,
#  'air-to-air': 87853,
#  'vistula': 60781,
#  'ice sculpture': 87854,
#  'ahoy': 184,
#  'or else': 87859,
#  'hirundinidae': 58336,
#  'canvasses': 186,
#  'dutchy': 87865,
#  'musculophrenic': 87867,
#  'common kingsnake': 87868,
#  'champers': 87869,
#  'pachycephalosaurus': 87870,
#  'kickline': 87872,
#  'sheet pile': 87873,
#  'fipple flute': 87874,
#  'harle': 87878,
#  'conspiratorial': 1294,
#  'mechanomyogram': 87880,
#  'colation': 87882,
#  'besmile': 87884,
#  'intercoastal': 87885,
#  'ghosting': 87888,
#  'close in': 271840,
#  'ill health': 87889,
#  'pang': 199,
#  'video rhythm': 87893,
#  'scientific fact': 213717,
#  'incisory': 87897,
#  'cigar': 202,
#  'rodomontade': 208,
#  'conjugal visitation': 87906,
#  'nonremote': 87909,
#  'unvanished': 87914,
#  'bioclast': 87911,
#  'workableness': 87620,
#  'ammoniate': 87920,
#  'draw a bath': 87922,
#  'zoutch': 87924,
#  'napa': 844,
#  'plurality': 229,
#  'taxidermist': 231,
#  'pneumatically': 232,
#  'tuvaluan': 234,
#  'aeromechanic': 87929,
#  'benzoxepine': 87931,
#  'graphician': 87933,
#  'vampirological': 87937,
#  'greatness': 239,
#  'Weill': 87936,
#  'cargoes': 242,
#  'shuffleboard': 1523,
#  'nisey': 87938,
#  'vomiturition': 87942,
#  'ill-used': 87940,
#  'barber shop': 87943,
#  'reaudit': 87944,
#  'copayment': 87945,
#  'mislodge': 87946,
#  'penetrometer': 87947,
#  'baddies': 87948,
#  'forgettest': 87630,
#  'november': 250,
#  'Christological': 172601,
#  'splint bone': 87950,
#  'recommend': 252,
#  'jade': 1603,
#  'nonbasalt': 87955,
#  'Shua': 174954,
#  'hydrolyse': 256,
#  'osmanthus': 257,
#  'canker brake': 87963,
#  'dyeable': 87964,
#  'insculption': 87965,
#  'improsperity': 87966,
#  'half and half': 87967,
#  'wireweed': 87968,
#  'mamilla': 87969,
#  'paleola': 87973,
#  'fieri facias': 174953,
#  'househusband': 87976,
#  'born with a silver spoon in ones mouth': 87977,
#  'trackscout': 87980,
#  'dutch west indies': 87634,
#  'shiitake': 87981,
#  'skim off': 87985,
#  'basket': 270,
#  'cauline': 87636,
#  'azimuth circle': 87986,
#  'fortunate': 274,
#  'Augustinian Hermits': 87990,
#  'pothunter': 278,
#  'twenty-two rifle': 87992,
#  'diubiquitylated': 87996,
#  'Odontaspididae': 87994,
#  'reglucosylate': 87998,
#  'nickelalumite': 87999,
#  'discounting': 283,
#  'performance art': 88002,
#  'nikolis': 88003,
#  'speeches': 284,
#  'have kittens': 88005,
#  'poes': 64013,
#  'intercommunicate': 286,
#  'acrolect': 290,
#  'chronometer': 292,
#  'choralelike': 88012,
#  'amplify': 12198,
#  'low-tech': 88014,
#  'vincent': 294,
#  'leavening': 296,
#  'photoevaporating': 88019,
#  'cosmologist': 58350,
#  'discerns': 24075,
#  'Philadelphus coronarius': 88024,
#  'impaled': 298,
#  'pipidae': 299,
#  'cruciation': 88027,
#  'adulator': 88029,
#  'ash-bin': 88030,
#  'ornamenter': 88032,
#  'comfortableness': 304,
#  'ethchlorvynol': 88035,
#  'kempite': 88037,
#  'tinged': 306,
#  'Orinoco': 87647,
#  'get into trouble': 88041,
#  'hydrolyzing': 308,
#  'Frederick I': 88042,
#  'Aegiceras majus': 88043,
#  'natalitial': 88044,
#  'globe lily': 88045,
#  'magnetron': 88046,
#  'Eurasiatic': 289649,
#  'lunar time period': 174970,
#  'pockmarked': 314,
#  'combi': 88055,
#  'narwhal': 35833,
#  'analogueanalog': 54270,
#  'cholic acid': 88058,
#  'zamenhof': 21152,
#  'nonstriped': 88064,
#  'biradial': 19877,
#  'guttiform': 88065,
#  'unromanticized': 88068,
#  'stereotyped': 326,
#  'teachers': 329,
#  'unfalsified': 88077,
#  'crucible steel': 88074,
#  'hindermost': 333,
#  'brugmansia suaveolens': 174971,
#  'hyperlexic': 88082,
#  'hamamelid dicot genus': 88080,
#  'placekick': 88083,
#  'potato bread': 87651,
#  'at odds': 88084,
#  'volteface': 340,
#  'sports section': 88088,
#  'crosspieces': 343,
#  'murderess': 174975,
#  'Ummah': 88091,
#  'honeymoon period': 88093,
#  'hemoprotein': 353,
#  'Gian Carlo Menotti': 88095,
#  'eger': 88096,
#  'potassium acesulfame': 88102,
#  'vulnose': 88101,
#  'predeceases': 29002,
#  'fag hag': 88106,
#  'wartime': 362,
#  'hilar': 363,
#  'pompano': 2289,
#  'midfrequency': 88111,
#  'narcoanalytical': 88112,
#  'concessionary': 370,
#  'genus Macropus': 88116,
#  'inga': 371,
#  'nonfamiliarity': 88122,
#  'tardation': 88125,
#  'epitaph': 372,
#  'electrosynthesis': 88127,
#  'meaningful': 64540,
#  'bed rest': 88129,
#  'Pope Alexander VI': 88130,
#  'handcuffs': 378,
#  'inharmonic': 88133,
#  'axino': 88134,
#  'eigenclass': 88136,
#  'pack ice': 88137,
#  'iris pigmented epithelium': 88138,
#  'National Park Service': 174982,
#  'asis': 385,
#  'Ozothamnus': 88144,
#  'Masticophis': 88145,
#  'charkha': 88146,
#  'tokenizer': 88147,
#  'platinocyanic': 88148,
#  'purplewhite': 394,
#  'genus Chlamydosaurus': 129594,
#  'Karl Jaspers': 88152,
#  'glow tube': 88155,
#  'alreadyinternallymotivated': 400,
#  'candy corn': 88158,
#  'waded': 401,
#  'pali-': 88159,
#  'deamidation': 88160,
#  'ludification': 88161,
#  'overshorten': 174988,
#  'maniable': 88164,
#  'paraphillia': 87664,
#  'unobserved': 404,
#  'letuary': 88167,
#  'facial muscle': 88172,
#  'centeredness': 88173,
#  'breakpoint': 88175,
#  'lowerranked': 412,
#  'countermotion': 88178,
#  'Gram-positive': 88180,
#  'brunion': 88181,
#  'racing car': 88182,
#  'rube goldberg machine': 156304,
#  'geophilic': 88186,
#  'folksong': 419,
#  'bullock`s heart': 88191,
#  'retroactivity': 88194,
#  'Realtor': 88195,
#  'gun lobby': 88196,
#  'regime': 422,
#  'incuriousness': 88198,
#  'whipstock': 425,
#  'the race that stops a nation': 88202,
#  'Wise Men': 88205,
#  'heptafluoride': 88207,
#  'misregard': 88208,
#  'canaliculate': 88210,
#  'levitra': 434,
#  'order Lycoperdales': 88212,
#  'concretise': 88214,
#  'dahling': 251951,
#  'tight loop': 88217,
#  'amnesic': 84112,
#  'pileup': 88220,
#  'Laskar Jihad': 88222,
#  'butterfly-shaped': 174997,
#  'ayacut': 88223,
#  'sincerely': 442,
#  'dandler': 88224,
#  'arc cosecant': 88225,
#  'Lord`s Day': 88227,
#  'seeks': 29016,
#  'firebellied': 2724,
#  'verbolatry': 450,
#  'sixteenthcentury': 451,
#  'iproheptine': 88234,
#  'polygonales': 2747,
#  'inertly': 88236,
#  'land': 58373,
#  'interacted': 458,
#  'mallard': 459,
#  'xliv': 88245,
#  'Solanum macranthum': 88246,
#  'a stopped clock is right twice a day': 88250,
#  'home-farm': 88251,
#  'horsey set': 88253,
#  'outlying field': 88255,
#  'lightspeed': 175001,
#  'thank god': 88259,
#  'assay-mark': 88260,
#  'multifunction': 88264,
#  'acauline': 88263,
#  'antivascular': 88266,
#  'micrometrical': 88272,
#  'Bart': 88268,
#  'hyparterial': 88275,
#  'deplumation': 88274,
#  'waybread': 88277,
#  'phacops': 88280,
#  'nanoscopy': 88278,
#  'genus Lepomis': 88279,
#  'conditionate': 262916,
#  'cabinetry': 475,
#  'incremate': 88282,
#  'moe': 88284,
#  'keepie-uppie': 88283,
#  'Coracias': 88286,
#  'pennines': 2939,
#  'lecanoraceae': 2949,
#  're-edit': 88289,
#  'notcher': 88292,
#  'Selkup': 88294,
#  'mevalonic acid': 88297,
#  'douncer': 88298,
#  'Church of England': 88300,
#  'paraquat': 255540,
#  'ototoxic': 485,
#  'meiosis': 486,
#  'sweet cassava': 88305,
#  'metamorphous': 88307,
#  'tajikistan': 488,
#  'Presbyterianism': 88312,
#  'masculineness': 88313,
#  'web design': 88314,
#  'peoria': 88315,
#  'Nitrobacteriaceae': 88318,
#  'Bering Standard Time': 88319,
#  'Hypericum hypericoides': 88322,
#  'compressive': 495,
#  'real mode': 87682,
#  'unbottomed': 88324,
#  'norcholestane': 88326,
#  'endohedrally': 88328,
#  'oenophilia': 262924,
#  'arsenosugar': 88332,
#  'Ember Day': 88334,
#  'multiphonon': 88339,
#  'intoxicating': 504,
#  'stepper': 88340,
#  'slaughterous': 88342,
#  'sedimentation rate': 88344,
#  'incapacitated': 510,
#  'when pigs fly': 175021,
#  'minibreak': 88349,
#  'rethoryke': 88351,
#  'Cypripedium calceolus': 88350,
#  'surrealists': 513,
#  'vermiculated': 516,
#  'proto': 517,
#  'North Korean won': 88355,
#  'exomoon': 88356,
#  'raion': 87687,
#  'rockinhabiting': 522,
#  'Leto': 88358,
#  'diffusive': 523,
#  'fluidity': 524,
#  'depict': 525,
#  'caliginousness': 88364,
#  'blue fox': 88366,
#  'biggin': 88367,
#  'family Crassulaceae': 88370,
#  'rustication': 3288,
#  'keirin': 88373,
#  'citrus': 532,
#  'hindian': 88379,
#  'Easter card': 88383,
#  'clxxx': 88384,
#  'ganch': 88386,
#  'Maimonides': 88388,
#  'thonged': 88389,
#  'impossible': 537,
#  'materiomics': 160376,
#  'muckle': 88394,
#  'jaileress': 88397,
#  'loaded down': 88401,
#  'rinds': 76056,
#  'median value': 88403,
#  'hell dust': 88404,
#  'pimp': 546,
#  'nonfiction': 548,
#  'mcgovernite': 88408,
#  'terephthalic acid': 153702,
#  'vexing': 3457,
#  'twentiethly': 88414,
#  'taxophytina': 23858,
#  'tanoan': 559,
#  'zolimidine': 88416,
#  'Carina': 88418,
#  'puberty': 560,
#  'artificial horizon': 88419,
#  'wild': 563,
#  'bibliology': 88422,
#  'false truffle': 88423,
#  'football coach': 88424,
#  'elbow pad': 88429,
#  'best': 568,
#  'trio sonata': 88432,
#  'August 15': 175029,
#  'godmoder': 88433,
#  'self-evident': 88434,
#  'virga': 58399,
#  'vocal band': 88435,
#  'central business district': 88437,
#  'anoxybiosis': 88439,
#  'roman ring': 88442,
#  'battery-powered': 88443,
#  'antifebrine': 88444,
#  'exemplifies': 577,
#  'portoir': 88448,
#  'tetrafluoroethylene': 88450,
#  'rower': 580,
#  'Brasenia': 88455,
#  'epidendron': 88457,
#  'healing': 3664,
#  'unprojected': 88464,
#  'bromothymol blue': 88462,
#  'substituting': 585,
#  'ileocolic vein': 88465,
#  'plan a': 88468,
#  'cloud species': 88471,
#  'unstimulating': 88474,
#  'heterofullerene': 175040,
#  'neuroserpin': 88477,
#  'ullage': 88478,
#  'nonamputee': 175045,
#  'battle-axe': 88481,
#  'conscientious objector': 88482,
#  'kizami': 88487,
#  'clapped': 61176,
#  'malignant melanoma': 88488,
#  'toccatalike': 88491,
#  'pannose': 88490,
#  'capital of Oman': 259599,
#  'Sir Paul Gavrilovich Vinogradoff': 88492,
#  'intergalactic': 604,
#  'imperceptive': 88494,
#  'reencourage': 88498,
#  'nomologic': 88497,
#  'allomorphs': 610,
#  'ebrillade': 88501,
#  'adnear': 3819,
#  'shoe shop': 88502,
#  'fire-fanged': 88503,
#  'blindsight': 88505,
#  'INR': 88509,
#  'unshuffled': 88510,
#  'tenters': 85219,
#  'false dawn': 87709,
#  'tail lamp': 88511,
#  'panchromatically': 88513,
#  'hyperkinetic syndrome': 175046,
#  'renditions': 618,
#  'fastigiate': 3879,
#  'romanticised': 101966,
#  'nonfishery': 88517,
#  'United Kingdom': 88519,
#  'nonplacement': 88520,
#  'senior vice president': 88521,
#  'dipleidoscope': 88522,
#  'luxury liner': 88523,
#  'unclipped': 76073,
#  'wistest': 88528,
#  'favoredness': 88530,
#  'midward': 175054,
#  'xystarch': 88532,
#  'cutting off': 88531,
#  'digestive tract': 88537,
#  'bumpy bits': 87715,
#  'neuropsychopharmacology': 175053,
#  'as you like': 214000,
#  'irritates': 632,
#  'moose maple': 88543,
#  'gluonic': 88546,
#  'power broker': 88547,
#  'tenuirostral': 88550,
#  'bed jacket': 88553,
#  'disquieter': 88556,
#  'honey plant': 87717,
#  'walloper': 88564,
#  'oddsmaker': 88566,
#  'moabi': 175059,
#  'desensitisation': 88567,
#  'pooty': 87719,
#  'apple strudel': 88569,
#  'grippe': 654,
#  'black friars': 88571,
#  'icescape': 88573,
#  'lighting circuit': 88575,
#  'diversification': 660,
#  'comprehensiveness': 12521,
#  'rakehelly': 87722,
#  'pugnus': 31730,
#  'cell death': 88582,
#  'tit': 666,
#  'calculable': 670,
#  'nabu': 671,
#  'trademarks': 672,
#  'ideologue': 175064,
#  'distractible': 88591,
#  'astrophic': 88592,
#  'capnomor': 88593,
#  'Isoetaceae': 262954,
#  'mentalize': 88596,
#  'genus Phenacomys': 88597,
#  'Townsendia Exscapa': 88600,
#  'vanload': 88601,
#  'rustyedged': 683,
#  'pleonaste': 88602,
#  'tachocline': 88603,
#  'accombination': 87728,
#  'machine rifle': 88608,
#  'evesdrop': 88609,
#  'jets': 688,
#  'melancholily': 88612,
#  'dita': 88614,
#  'wages': 690,
#  'or-': 88615,
#  'family Tricholomataceae': 87730,
#  'paddlewheel': 694,
#  'crassiment': 88618,
#  'tide waiter': 88619,
#  'triumphus': 4304,
#  'uninheritable': 88620,
#  'tillable': 29059,
#  'flative': 88626,
#  'guesstimation': 87734,
#  'digitalization': 88627,
#  'htpc': 88632,
#  'deaf-muteness': 88631,
#  'reservedness': 88636,
#  'brisk': 58420,
#  'genus Cardium': 88637,
#  'underheat': 88639,
#  'indoaniline': 88641,
#  'important': 708,
#  'samoyedicspeaking': 50559,
#  'disgracer': 88647,
#  'machine gunner': 88646,
#  'scirpus': 710,
#  'patriarchically': 87735,
#  'jealousy': 713,
#  'collabo': 88650,
#  'espinel': 88651,
#  'escapists': 716,
#  'unceasable': 88654,
#  'kolicite': 88655,
#  'extramarital sex': 88656,
#  'precooled': 88657,
#  'chlorpropamide': 88659,
#  'dry battery': 88660,
#  'photoevaporated': 88662,
#  'self-aggrandising': 88664,
#  'course of lectures': 88665,
#  'thorn in the flesh': 88669,
#  'genus Turritis': 88670,
#  'clarifies': 724,
#  'thermotaxic': 88674,
#  'tractably': 88676,
#  'parakeets': 729,
#  'thirty-seven': 88678,
#  'overkeep': 87738,
#  'pamphleteer': 731,
#  'dipterocarpaceae': 732,
#  'knee high to a grasshopper': 88682,
#  'nonrailway': 175076,
#  'azulenes': 88687,
#  'chessboard': 739,
#  'idiot-proof': 88690,
#  'muddily': 87743,
#  'outrigger': 58428,
#  'nationhood': 88694,
#  'Canis aureus': 88696,
#  'milk': 746,
#  'breithauptite': 88698,
#  'irretractile': 88700,
#  'perfumey': 88702,
#  'commoved': 88704,
#  'yuksporite': 88706,
#  'piningly': 88710,
#  'portuguesespeaking': 752,
#  'hohlraum': 88712,
#  'mountweazel': 88716,
#  'disburser': 88717,
#  'oxyhemoglobin': 45360,
#  'energized': 757,
#  'pollen counter': 88719,
#  'salarium': 759,
#  'potholes': 761,
#  'drop a brick': 88720,
#  'hydrogen air': 88726,
#  'posse comitatus': 88724,
#  'fangy': 88725,
#  'french somaliland': 175084,
#  'forkmaker': 88732,
#  'Pomacentrus': 88733,
#  'eggburger': 88734,
#  'apt.': 88736,
#  'reprints': 771,
#  'inbuild': 88743,
#  'Boniface VIII': 88744,
#  'unititular': 241600,
#  'common beech': 262976,
#  'intumescence': 88748,
#  'knock for a loop': 88752,
#  'baldaquin': 88753,
#  'leftrotating': 777,
#  'vidette': 88762,
#  'Baffin Bay': 88763,
#  'insecurely': 780,
#  'utiliser': 88766,
#  'solidifies': 785,
#  'lucidol': 88769,
#  'chemical action': 262982,
#  'evil spirit': 88772,
#  'spinybacked': 788,
#  'walt': 789,
#  'lumbricus': 4933,
#  'prednisone': 88778,
#  'extranoematic': 88779,
#  'bracelet': 793,
#  'genus Galago': 88782,
#  'arc sine': 88784,
#  'sea-parrot': 87765,
#  'fierceness': 798,
#  'stipulated': 799,
#  'sympathy': 801,
#  'lepidosaur': 88795,
#  'hogpen': 88797,
#  'landplane': 88796,
#  'volume-detonation bomb': 88800,
#  'carpathians': 805,
#  'sky pilot': 88802,
#  'panto': 88804,
#  'reevaporate': 88806,
#  'isolysis': 88809,
#  'primitive': 29076,
#  'long-shanked': 88811,
#  'inactuate': 250918,
#  'boggles': 814,
#  'year mark': 88818,
#  'xxxiv': 88820,
#  'fleshless': 817,
#  'nonparticipating': 88823,
#  'wardship': 821,
#  'silveryblue': 822,
#  'lemon-wood': 88829,
#  'lorication': 88831,
#  'carotic': 825,
#  'appetizingness': 826,
#  'angelica': 827,
#  'melting': 831,
#  'tide rip': 88839,
#  'Evergreen State': 88840,
#  'Republic of Kiribati': 88843,
#  'stipule': 838,
#  'angular momentum': 88847,
#  'inculcation': 840,
#  'choropleth map': 87769,
#  'musculus adductor hallucis': 88849,
#  'limbic system': 88850,
#  'clatty': 88853,
#  'colorrelated': 845,
#  'dekameter': 88861,
#  'benzanthracene': 88863,
#  'spot-welder': 88865,
#  'Koln': 88866,
#  'nitrolysis': 87772,
#  'arabinofuranose': 88868,
#  'Ictiobus': 88870,
#  'ichomage': 88873,
#  'abruptest': 88874,
#  'inconveniently': 852,
#  'hard-baked': 88877,
#  'unctuousness': 853,
#  'close the stable door after the horse has bolted': 88882,
#  'foetor': 88884,
#  'litidionite': 88885,
#  'calvinize': 88886,
#  'overcomes': 859,
#  'chen': 860,
#  'haptophyte': 88890,
#  'slab': 862,
#  'perfectness': 29084,
#  'batful': 88895,
#  'flat-chestedness': 88896,
#  'war bride': 167214,
#  'jamberry': 88897,
#  'mesicke': 88899,
#  'noblesse oblige': 88900,
#  'bill of lading': 88903,
#  'damage control': 304726,
#  'pejorative': 871,
#  'tabanidae': 872,
#  'deoxyadenosines': 123124,
#  'gaincope': 88905,
#  'liquorish': 88908,
#  'invading': 876,
#  'creasy': 263006,
#  'handmaidenly': 88910,
#  'metronome marking': 88911,
#  'horn': 29088,
#  'Lewisia cotyledon': 88912,
#  'uptight': 5500,
#  'monensin': 88913,
#  'polarizes': 5516,
#  'subconscious mind': 88917,
#  'axeblade': 88919,
#  'culverkey': 263007,
#  'chechen-ingush autonomous oblast': 88928,
#  'feldspar': 889,
#  'enviably': 890,
#  'genus Centropus': 88930,
#  'myxoma': 87779,
#  'vincristine': 88931,
#  'trandolapril': 88932,
#  'engineering school': 88933,
#  'Republic of Kazakhstan': 88935,
#  'term of office': 88937,
#  'mortality table': 88939,
#  'intertalk': 88940,
#  'hush up': 88942,
#  'barnfloor': 88943,
#  'send on': 88945,
#  'gismondine': 88949,
#  'megakaryopoiesis': 88952,
#  'cyberloafing': 88953,
#  'wooldridgeite': 88955,
#  'Rhus ovata': 88956,
#  'dfdx': 72034,
#  'love rat': 87786,
#  'martuthunira': 88963,
#  'selfassertion': 58454,
#  'advantageousness': 88964,
#  'hugy': 88967,
#  'Fundulus majalis': 88966,
#  'sibilant consonant': 88969,
#  'mizzy': 88972,
#  'sursum corda': 88973,
#  'apartment': 912,
#  'flattopped': 914,
#  'quarterstaff': 915,
#  'oldstyle': 916,
#  'aspartame': 918,
#  'dill': 919,
#  'hash sign': 88978,
#  'below the belt': 88979,
#  'vertebral': 920,
#  'dumka': 88983,
#  'genus Chilomycterus': 88985,
#  'plo': 922,
#  'hypocaust': 924,
#  'ballistic pendulum': 88995,
#  'biophysics': 929,
#  'necrotizing enteritis': 89002,
#  'ameboid': 175125,
#  'citizenhood': 89006,
#  'noiselessness': 87789,
#  'merseyside': 14792,
#  'emplead': 89008,
#  'unavailingness': 89010,
#  'rhumb': 939,
#  'gluttonous': 940,
#  'behated': 175127,
#  'noninterview': 89014,
#  'merciful': 946,
#  'recipes': 949,
#  'black-headed snake': 89020,
#  'toyhouse': 87796,
#  'murex': 89023,
#  're-ally': 89024,
#  'aeneolithic': 89025,
#  'heterodisaccharide': 89027,
#  'oct-': 89033,
#  'tongue-twister': 89035,
#  'oxidized': 958,
#  'academic administrator': 89036,
#  'rough sledding': 89037,
#  'Ixodes spinipalpis': 89038,
#  'Fabiana imbricata': 89040,
#  'allotropical': 89042,
#  'football player': 89045,
#  'Transfiguration Day': 87800,
#  'potage': 89046,
#  'recount': 963,
#  'Nellie Tayloe Ross': 89047,
#  'polygene': 89048,
#  'thugging': 89051,
#  'diplegic': 89057,
#  'moustachioed': 89062,
#  'abfarad': 89063,
#  'pseudoscience': 972,
#  'nonorphan': 89071,
#  'abs-': 89070,
#  'prolixity': 978,
#  'abatement': 23873,
#  'oppugner': 128083,
#  'transversal': 984,
#  'phenomenology': 6092,
#  'perspirability': 89085,
#  'hardtop': 89088,
#  'uncircumnavigated': 89090,
#  'mentoplasty': 89091,
#  'lipitor': 6117,
#  'sesame oil': 87808,
#  'eosophobia': 89092,
#  'hypnotizability': 89097,
#  'fermat': 994,
#  'fair wind': 89099,
#  'fucose': 995,
#  'macroinstruction': 89101,
#  'carabineer': 89103,
#  'shirburnian': 89107,
#  'abrasion platform': 89104,
#  'ort': 89108,
#  'checkpoints': 1000,
#  'diiodomethane': 89110,
#  'tomatobased': 1002,
#  'epiphonema': 89112,
#  'positron emission tomography scanner': 89111,
#  'punt': 1004,
#  'recan': 89119,
#  'bronzes': 1008,
#  'irreverence': 1009,
#  'class act': 89121,
#  'landmine': 1011,
#  'intaglio': 1012,
#  'auriculare': 89123,
#  'genus Phragmipedium': 89124,
#  'PST': 89125,
#  'futuristic': 1013,
#  'rossmanite': 89135,
#  'juanite': 89129,
#  'disauthorize': 89133,
#  'Sebastodes miniatus': 89131,
#  'new thought': 89132,
#  'hyalinization': 89137,
#  'ovo-viviparous': 89138,
#  'Victoria Clafin Woodhull': 89139,
#  'cancrisilite': 89141,
#  ...}

# %%
def generate_batch(sequence,window_size,filler=-1):
    
    '''Function which generates a set of batches from int-like sequence
    default argument filler (-1) could be changed accoring to your needs'''
    
    batchesX = []
    batchesY = []
    
    if len(sequence)>window_size: 
        
        for index,num in enumerate(sequence):
            range1 = sequence[index-window_size:index]
            range2 = sequence[index+1:index+window_size+1]

            if len(range1) is not window_size:
                range1 = [filler]*(window_size-len(range1)) + range1

            if len(range2) is not window_size:
                range2 = range2 + [filler]*(window_size-len(range2))

            batchesX.append(range1+range2)
            batchesY.append(num)
            
    else:
        
        return None,None
        
    return (batchesX,batchesY)

# %%
def generate_batches(enc_sequences,window_size=3): 
    
    '''Function which iteratevely generate batches through encoded sequence'''
    
    batchesX=[]
    batchesY=[]
    for value in enc_sequences:
        batchX , batchY = generate_batch(value,window_size)
        if batchX is not None:
            batchesX.append(np.array(batchX,dtype=np.int32))
            batchesY.append(np.array(batchY,dtype=np.int32))
            
    return (batchesX,batchesY)

# %%
batchesX,batchesY=generate_batches(encoded)

# %%
def pregen_equally_sized_batch(batchesX,batchesY,batch_size=256):
    
    '''First part of generator chain in order to save some computation time' and make batches of the same shape'''
    
    batchX,batchY = generate_empty_batches_array()
    
    for batch in zip(batchesX,batchesY):
        for i in range(len(batch[0])):
            X_sample = batch[0][i] 
            Y_sample = batch[1][i]
            batchX.append(X_sample)
            batchY.append(Y_sample)
            if len(batchX)==batch_size:
                
                batchX,batchY = np.array(batchX,dtype=np.int32),np.array(batchY,dtype=np.int32) 
                
                yield (batchX,batchY)
                batchX,batchY = generate_empty_batches_array()

# %%
def gen_batch(batchesX,batchesY,batch_size=256):
    
    batchX,batchY = generate_empty_batches_array()
    pregen = pregen_equally_sized_batch(batchesX,batchesY,batch_size)
    for batch in pregen:
        for index1,center in enumerate(batch[1]):
            for index2,target in enumerate(batch[0][index1]):
                if target!=-1 and target!=-2 and center!=-2:
                    batchX.append(center)
                    batchY.append(target)
                    if len(batchX)==batch_size:
                        indices = np.random.permutation(batch_size)
                        batchX ,batchY= np.array(batchX),np.array(batchY).reshape(-1,1)
                        batchX , batchY = batchX[indices],batchY[indices]
                        yield(batchX,batchY)
                        batchX,batchY = generate_empty_batches_array()

# %%
def generate_empty_batches_array():
    ''' Name of function is self-explanatory'''
    
    batchesX=[]
    batchesY=[]
    
    return (batchesX,batchesY)

# %%
class Word2Vec:
    
    def __init__(self,batch_size,word_to_int,embedding_size,learning_rate,training_steps):
        tf.reset_default_graph()
        self.batch_size=batch_size
        self.vocab_len=len(word_to_int)
        self.word_to_int=word_to_int
        self.embedding_size = embedding_size
        self.learning_rate = learning_rate
        self.training_steps=training_steps
        self.init_vars()
       
        
    def init_vars(self):
        
        with tf.name_scope("data"):
            self.center_words = tf.placeholder(dtype=tf.int32,shape=[self.batch_size],name="self.center_words")
            self.target_words = tf.placeholder(dtype=tf.int32,shape=[self.batch_size,1],name="self.target_words")
            self.global_step = tf.Variable(0,trainable=False,name="global_step")
            
        with tf.name_scope("embed"):
            self.embedding_matrix = tf.Variable(tf.random_uniform([self.vocab_len,self.embedding_size],-1.0,1.0),name="embedding_matrix")
           
        with tf.name_scope("loss"):
            self.embedding = tf.nn.embedding_lookup(self.embedding_matrix,self.center_words,name="embed")
            self.nce_weights = tf.Variable(tf.truncated_normal([self.vocab_len,self.embedding_size],stddev=1/(self.embedding_size**0.5)),
                                      name="nce_weights")
            self.nce_biases = tf.Variable(tf.zeros([self.vocab_len]),name="nce_biases")
            
            self.loss = tf.reduce_mean(tf.nn.nce_loss(weights=self.nce_weights, 
                                            biases=self.nce_biases, 
                                            labels=self.target_words, 
                                            inputs=self.embedding, 
                                            num_sampled=64, 
                                            num_classes=self.vocab_len), name='loss')
                           
                                        
        with tf.name_scope("summary"):
            tb_loss=tf.summary.scalar("loss",self.loss)
            tb_hs_loss=tf.summary.histogram("histogram_loss",self.loss)
            self.summary_op = tf.summary.merge([tb_loss,tb_hs_loss])
                                     
                                     
        self.optimizer = tf.train.GradientDescentOptimizer(learning_rate=self.learning_rate).minimize(self.loss,global_step=self.global_step)
        
        
        
        
        self.batch_gen=gen_batch(batchesX,batchesY,self.batch_size)
        self.average_loss=0.0
        self.saver = tf.train.Saver()
       
    def visualize_embeddings(self):
            with tf.Session() as sess:
                sess.run(tf.global_variables_initializer())

                self.saver.restore(sess,save_path="checkpoint_dir/word2vec-283331")
                for v in tf.trainable_variables():

                    if v.name=="embed/embedding_matrix:0":
                        result=v


                final_embed_matrix = sess.run(result)
                print(final_embed_matrix)


                # # it has to variable. constants don't work here. you can't reuse model.embed_matrix
                embedding_var = tf.Variable(final_embed_matrix, name='embedding')
                sess.run(embedding_var.initializer)

                config = projector.ProjectorConfig()
                summary_writer = tf.summary.FileWriter('processed')

                 # add embedding to the config file
                embedding = config.embeddings.add()
                embedding.tensor_name = embedding_var.name

                # # link this tensor to its metadata file, in this case the first 500 words of vocab
                embedding.metadata_path = 'vocab_all_words.tsv'

               # saves a configuration file that TensorBoard will read during startup.
                projector.visualize_embeddings(summary_writer, config)
                saver_embed = tf.train.Saver([embedding_var])
                saver_embed.save(sess, 'processed/model.ckpt', 1)
                summary_writer.close()

                
    def save(self,sess,global_step):
        directory = "checkpoint_dir/word2vec"
        self.saver.save(sess,directory,global_step)
        return global_step
        

   

    def execute_training(self):
            
            with tf.Session() as sess:

                sess.run(tf.global_variables_initializer())
                time0 = time.time()
                self.writer=tf.summary.FileWriter("./stats",sess.graph)

                for i in range(self.training_steps):

                    try:
                        batch = next(self.batch_gen)
                        center_word = batch[0]
                        target_word = batch[1]
                    except StopIteration:
                        self.global_step=self.save(sess,i)
                        self.writer.close()
                        break

                    feed_dict = {self.center_words:center_word,self.target_words:target_word}

                    loss_get,_,summary= sess.run([self.loss,self.optimizer,self.summary_op],feed_dict = feed_dict)

                    self.average_loss+=loss_get
                    self.writer.add_summary(summary,global_step = i)
                    

                    if (i+1) % 10000==0:
                        time1 = time.time()
                        print("Average loss at timestep {} is {:5.1f} , time to calculate {} s ".format(i+1,
                                                                           self.average_loss/i+1,round(time1-time0,3)))
                        time0 =time.time()
                    
                    if (i+1) %self.training_steps==0:
                        self.global_step = self.save(sess,i)



                self.writer.close()
                
                
    def load_words_to_file(self):
           
            FILE_PATH = "processed/vocab_all_words.tsv" 
            
            if not os.path.exists(FILE_PATH):
                words = self.word_to_int.keys()
                with open(FILE_PATH,"w") as file:
                       for word in words:
                            print(word,file=file)

# %%
model = Word2Vec(batch_size=64,embedding_size=128,word_to_int=word_to_index,learning_rate=2.0,training_steps=800000)

# %%
model.execute_training()
# Out:
# Average loss at timestep 10000 is 144.6 , time to calculate 29.023 s
# Average loss at timestep 20000 is 115.6 , time to calculate 25.849 s
# Average loss at timestep 30000 is  98.8 , time to calculate 33.087 s
# Average loss at timestep 40000 is  87.3 , time to calculate 34.543 s
# Average loss at timestep 50000 is  78.6 , time to calculate 35.67 s
# Average loss at timestep 60000 is  71.9 , time to calculate 29.793 s
# Average loss at timestep 70000 is  66.3 , time to calculate 32.281 s
# Average loss at timestep 80000 is  61.9 , time to calculate 26.501 s
# Average loss at timestep 90000 is  58.4 , time to calculate 28.757 s
# Average loss at timestep 100000 is  55.6 , time to calculate 32.926 s
# Average loss at timestep 110000 is  53.2 , time to calculate 32.783 s
# Average loss at timestep 120000 is  50.9 , time to calculate 29.787 s
# Average loss at timestep 130000 is  48.9 , time to calculate 32.295 s
# Average loss at timestep 140000 is  47.1 , time to calculate 31.933 s
# Average loss at timestep 150000 is  45.4 , time to calculate 27.592 s
# Average loss at timestep 160000 is  44.1 , time to calculate 26.269 s
# Average loss at timestep 170000 is  42.7 , time to calculate 26.413 s
# Average loss at timestep 180000 is  41.4 , time to calculate 25.965 s
# Average loss at timestep 190000 is  40.1 , time to calculate 26.346 s
# Average loss at timestep 200000 is  39.0 , time to calculate 25.889 s
# Average loss at timestep 210000 is  37.9 , time to calculate 25.954 s
# Average loss at timestep 220000 is  37.0 , time to calculate 26.38 s
# Average loss at timestep 230000 is  36.1 , time to calculate 25.745 s
# Average loss at timestep 240000 is  35.3 , time to calculate 26.502 s
# Average loss at timestep 250000 is  34.5 , time to calculate 25.856 s
# Average loss at timestep 260000 is  33.8 , time to calculate 26.471 s
# Average loss at timestep 270000 is  33.2 , time to calculate 26.224 s
# Average loss at timestep 280000 is  32.5 , time to calculate 27.883 s
# Average loss at timestep 290000 is  31.9 , time to calculate 26.251 s
# Average loss at timestep 300000 is  31.3 , time to calculate 26.047 s
# Average loss at timestep 310000 is  30.8 , time to calculate 26.76 s
# Average loss at timestep 320000 is  30.3 , time to calculate 25.954 s
# Average loss at timestep 330000 is  29.9 , time to calculate 26.772 s
# Average loss at timestep 340000 is  29.4 , time to calculate 25.846 s
# Average loss at timestep 350000 is  29.0 , time to calculate 26.049 s
# Average loss at timestep 360000 is  28.6 , time to calculate 25.726 s
# Average loss at timestep 370000 is  28.2 , time to calculate 25.481 s
# Average loss at timestep 380000 is  27.8 , time to calculate 26.129 s
# Average loss at timestep 390000 is  27.5 , time to calculate 25.994 s
# Average loss at timestep 400000 is  27.1 , time to calculate 25.875 s
# Average loss at timestep 410000 is  26.8 , time to calculate 25.688 s
# Average loss at timestep 420000 is  26.4 , time to calculate 27.26 s
# Average loss at timestep 430000 is  26.1 , time to calculate 25.74 s
# Average loss at timestep 440000 is  25.8 , time to calculate 25.982 s
# Average loss at timestep 450000 is  25.6 , time to calculate 25.681 s
# Average loss at timestep 460000 is  25.3 , time to calculate 27.156 s
# Average loss at timestep 470000 is  25.1 , time to calculate 26.485 s
# Average loss at timestep 480000 is  24.9 , time to calculate 25.879 s
# Average loss at timestep 490000 is  24.7 , time to calculate 26.449 s
# Average loss at timestep 500000 is  24.4 , time to calculate 25.852 s
# Average loss at timestep 510000 is  24.2 , time to calculate 26.457 s
# Average loss at timestep 520000 is  24.0 , time to calculate 26.142 s
# Average loss at timestep 530000 is  23.8 , time to calculate 25.832 s
# Average loss at timestep 540000 is  23.8 , time to calculate 26.347 s
# Average loss at timestep 550000 is  23.7 , time to calculate 27.725 s
# Average loss at timestep 560000 is  23.6 , time to calculate 27.982 s

# %%
model.load_words_to_file()

# %%
model.visualize_embeddings()
# Out:
# INFO:tensorflow:Restoring parameters from checkpoint_dir/word2vec-283331
# [[ 0.06376919 -1.6537497  -1.26960015 ..., -0.82139474 -1.40726221
#   -0.59549248]
#  [-0.93887901  0.22774372 -0.82737404 ..., -0.16128071 -1.50214553
#   -0.50000304]
#  [ 0.03260875 -0.23994614  0.22925663 ..., -0.10199402 -0.9900254
#   -0.12052806]
#  ...,
#  [-0.28072786  0.28797293 -0.94665623 ..., -0.88811731  0.5270896
#   -0.0510006 ]
#  [-0.12864733 -0.41069007 -0.44026446 ...,  0.28916502  0.83757448
#    0.17500448]
#  [-0.92102695 -0.35959029  0.70663214 ...,  0.84626937  0.05432224
#   -0.6420176 ]]

# %%
gen = gen_batch(batchesX,batchesY)

# %%
model.visualize_embeddings = visualize_embeddings

# %%
word_to_index
# Out:
# {'': 87560,
#  'embulk': 87561,
#  'incompetency': 0,
#  'Decumaria barbara': 87563,
#  'handshake': 4,
#  'pazinaclone': 87570,
#  'preservatives': 43884,
#  'clearance': 8,
#  'claiming': 51215,
#  'podder': 87574,
#  'Malawi': 262441,
#  'escape valve': 87576,
#  'Fritz W. Meissner': 87565,
#  'bp': 65936,
#  'change-of-life': 87581,
#  'disapprovingly': 14,
#  'conveys': 16,
#  'befly': 87585,
#  'nonsepticemic': 87589,
#  'decadently': 87587,
#  'barberiite': 87596,
#  'vitreous humor': 87597,
#  'egad': 87599,
#  'US Post Office': 87600,
#  'contractedly': 87604,
#  'frog`s-bit': 87606,
#  'roosevelt': 31,
#  'nonearthbound': 87567,
#  'Transylvania': 87607,
#  'crested wheatgrass': 87610,
#  'hermaphroditic': 81609,
#  'parkinson': 87614,
#  'inserted': 36,
#  'twenty percent': 87617,
#  'decrepit': 42,
#  'sebastes': 44,
#  'take in charge': 87623,
#  'surface fire': 87624,
#  'heptadecenoic': 45,
#  'intermembranous': 87628,
#  'honeylike': 55904,
#  'outthink': 87631,
#  'fila': 87573,
#  'goalscorer': 23751,
#  'temporary state': 87635,
#  'leaderette': 87637,
#  'due north': 87640,
#  'hit the dirt': 87643,
#  'Amphiprion': 87645,
#  'declutter': 87647,
#  'rammel': 262458,
#  'genus Anabas': 174930,
#  'shawl': 64,
#  'avidinated': 87656,
#  'magnetoassociation': 87661,
#  'Simon the Zealot': 87662,
#  'bootup': 69,
#  'railways': 70,
#  'muciferous': 87664,
#  'Jan van der Meer': 87666,
#  'Prix Goncourt': 87670,
#  'elaborately': 75,
#  'shoreside': 87677,
#  'chalkpit': 174932,
#  'bake sale': 87675,
#  'antitobacco': 87678,
#  'Carpinus': 87679,
#  'implore': 65126,
#  'caudated': 262464,
#  'deergrass': 87682,
#  'genus Procnias': 87579,
#  'in a beastly manner': 87683,
#  'rehappen': 87690,
#  'denglisch': 87685,
#  'antistrophic': 87686,
#  'creases': 85,
#  'electee': 87695,
#  'fast buck': 87696,
#  'spoof': 88,
#  'extra-statutory': 87697,
#  'gin palace': 87698,
#  'jack oak': 87699,
#  'Noah': 87701,
#  'circumscriptive': 87580,
#  'antilogy': 174937,
#  'moral compass': 87705,
#  'family Trephritidae': 174939,
#  'emblazonry': 298062,
#  'fibrinolysis': 100,
#  'bubblicious': 87713,
#  'myopically': 101,
#  'natural resource': 87712,
#  'genus Afropavo': 269403,
#  'salivation': 103,
#  'meniscus': 28981,
#  'Mt. Vesuvius': 87716,
#  'ignorantly': 106,
#  'Quercus ilex': 87717,
#  'reformulations': 109,
#  'quiesce': 87722,
#  'maniverter': 87724,
#  'religous': 652,
#  'shipholder': 87725,
#  'jittering': 87726,
#  'deckhand': 114,
#  'gerontology': 117,
#  'magnesiosadanagaite': 87731,
#  'uncunt': 87732,
#  'Wednesday': 87733,
#  'casuarius': 119,
#  'larping': 87739,
#  'glasswashing': 87586,
#  'absentee': 720,
#  'concordancer': 87747,
#  'ventriculus': 128,
#  'igloos': 130,
#  'minioning': 87750,
#  'neumann': 770,
#  'joensuu': 87755,
#  'basic block': 87757,
#  'tarentula': 87593,
#  'animable': 87759,
#  'ensnarement': 87761,
#  'catherine': 813,
#  'food manufacturer': 262477,
#  'maccy ds': 87763,
#  'zincographical': 87766,
#  'statedly': 145,
#  'sluggard': 849,
#  'white bryony': 87768,
#  'creeping Charlie': 87770,
#  'in service': 87771,
#  'hyperinflated': 87776,
#  'inhalation anesthesia': 87775,
#  'tepui tinamou': 311899,
#  'Greek key': 87780,
#  'brandlike': 87781,
#  'chronogrammatist': 87784,
#  'shipoftheline': 156,
#  'Tayassu tajacu': 87785,
#  'franking machine': 87786,
#  'jerran': 87789,
#  'goodfaith': 28993,
#  'radio jock': 87791,
#  'tensometer': 87598,
#  'shari': 952,
#  'haliotidae': 161,
#  'tepui': 87795,
#  'circumambiency': 87797,
#  'Anu': 87798,
#  'plushophilia': 87799,
#  'sterilizing': 167,
#  'divisi': 87602,
#  'genus Linum': 87802,
#  'Egeria densa': 87803,
#  'yeastie beastie': 87804,
#  'nobiliate': 172,
#  'honker': 174,
#  'chickenshit': 87806,
#  'LCD': 87807,
#  'predicatively': 67331,
#  'kingdom of yemen': 87812,
#  'home reserve': 87605,
#  'pietist': 87819,
#  'clientelistic': 87825,
#  'emission spectrum': 87821,
#  'fronton': 87826,
#  'lady abbess': 87823,
#  'broomlike': 87829,
#  'Valdosta': 87832,
#  'lacrimal lake': 87833,
#  'north island brown kiwi': 87836,
#  'imbezzle': 87842,
#  'halloween': 184,
#  'geomagnetic': 185,
#  'gosan-chiku': 87845,
#  'vermiphobia': 87847,
#  'feminized': 187,
#  'grey wolf': 87848,
#  'seduced': 189,
#  'brought': 191,
#  'konitsa': 87858,
#  'oil color': 87859,
#  'outthrow': 87861,
#  'spiny-leafed': 87863,
#  'Macowanites': 87868,
#  'nexible': 167316,
#  'microautophagy': 87872,
#  'shipwright': 202,
#  'callant': 87875,
#  'Scomberomorus': 87877,
#  'observes': 205,
#  'Entomophthora': 87879,
#  'his royal highness': 87882,
#  'oxybenzene': 87885,
#  'altumomab': 87887,
#  'cross-garnet': 87888,
#  'cripply': 87891,
#  'regionalize': 87894,
#  'marchihue': 87895,
#  'contortionists': 212,
#  'inappropriateness': 1363,
#  'lemon-wood tree': 87899,
#  'fly biscuit': 87900,
#  'embodied': 217,
#  'vesbium': 87902,
#  'demersed': 87904,
#  'Lenin': 87905,
#  'plumbers snake': 87906,
#  'Aldomet': 87907,
#  'deindividuation': 87910,
#  'goof': 220,
#  'bay platform': 87911,
#  'janette': 87912,
#  'dolce': 87913,
#  'biblical blue': 87917,
#  'anura': 224,
#  'CIRA': 87921,
#  'farro': 87923,
#  'blackish-brown': 87924,
#  'electrical current': 87927,
#  'ean': 87930,
#  'tachygraphical': 87933,
#  'orthoformate': 87935,
#  'shotgun sequencing': 87936,
#  'benign prostatic hyperplasia': 87937,
#  'family Parkeriaceae': 87938,
#  'yellow birch': 87620,
#  'drop arch': 87942,
#  'Pharaoh of Egypt': 87945,
#  'astrochemistry': 238,
#  'stargaze': 87622,
#  'blood-and-guts': 87947,
#  'microcredit': 87022,
#  'Brachystegia': 87949,
#  'karlite': 87953,
#  'pyran': 6667,
#  'Mycobacterium tuberculosis': 347772,
#  'rex': 1566,
#  'Artemisia dracunculus': 87959,
#  'dropforge': 24311,
#  'collitigant': 87961,
#  'locked': 247,
#  'Hans Christian Andersen': 87962,
#  'maplike': 1583,
#  'demagnetization': 87964,
#  'paoli': 262497,
#  'unauthorised': 251,
#  'double room': 174983,
#  'contaminative': 87968,
#  'diandrian': 87970,
#  'achenial': 87973,
#  'Viola arvensis': 87974,
#  'silverware': 258,
#  'unsay': 259,
#  'calcined': 260,
#  'trade surplus': 87629,
#  'coactivated': 87980,
#  'stage crew': 87983,
#  'did': 265,
#  'Kwan-yin': 174986,
#  'gay-ass': 87986,
#  'hond': 174992,
#  'pass completion': 87992,
#  'compensative': 87994,
#  'glike': 87997,
#  'blandisher': 87996,
#  'nor-west': 262502,
#  'monotonal': 88002,
#  'illusionary': 270,
#  'silicates': 272,
#  'crabstick': 273,
#  'sappodilla': 88004,
#  'revenges': 275,
#  'neurodynamic': 88007,
#  'antimorph': 88009,
#  'Shenandoah Valley': 88010,
#  'aeronomic': 88012,
#  'yopo': 88015,
#  'weakest': 282,
#  'stow': 285,
#  'bilingual dictionary': 88019,
#  'subarachnoid': 287,
#  'unwiedly': 291,
#  'viaticum': 88022,
#  'paternity': 292,
#  'open-mouthed': 88023,
#  'person of colour': 88025,
#  'bunnyhug': 87633,
#  'lunch kettle': 88034,
#  'tertiary phosphine': 88036,
#  'digammate': 88033,
#  'Ohm`s law': 88037,
#  'czechness': 262510,
#  'saragossa': 301,
#  'exaltare': 303,
#  'habitue': 174995,
#  'shock': 29020,
#  'osler node': 88042,
#  'shrimpfish': 88044,
#  'piezophilic': 262515,
#  'jamborette': 88049,
#  'limited overs cricket': 88051,
#  'virological': 88052,
#  'emirati': 88053,
#  'hair moss': 286066,
#  'eye movement': 88056,
#  'ubiquinone': 314,
#  'wishfully': 316,
#  'steaks': 58179,
#  'ugrian': 317,
#  'redingote': 88066,
#  'resto': 88068,
#  'conversion factor': 88070,
#  'beryl': 2025,
#  'micropaleontological': 88072,
#  'homofunctionalized': 88075,
#  'parachlorophenoxyacetate': 87641,
#  'scripps': 326,
#  'extrarational': 88078,
#  'take a hop': 88080,
#  'balsam': 29024,
#  'cathartes': 10016,
#  'kussmaul breathing': 88083,
#  'purchasing department': 175003,
#  'non-scientific': 88084,
#  'National Labor Relations Board': 175004,
#  'plotting': 36617,
#  'mesonephros': 339,
#  'penalty goal': 88093,
#  'virogenesis': 87649,
#  'Euryalida': 262524,
#  'scuffed': 344,
#  'eidetic memory': 175009,
#  'cheerlessness': 345,
#  'geochronometry': 88100,
#  'Dinoflagellata': 88104,
#  'eastern tarantula': 88105,
#  'loblolly boy': 88107,
#  'downstep': 88109,
#  'benign tumor': 88110,
#  'roman numerals': 88112,
#  'nongoods': 88114,
#  'nighest': 88115,
#  'palace of westminster': 88116,
#  'dehypnotize': 88117,
#  'comely maidens': 88120,
#  'turbidly': 87652,
#  'persephone': 355,
#  'plesiosauria': 43723,
#  'increated': 262530,
#  'Spheniscidae': 88125,
#  'venturesomely': 88132,
#  'coleridgian': 366,
#  'intermediator': 88134,
#  'family Aplysiidae': 88135,
#  'tellurolate': 88136,
#  'four-fold': 88137,
#  'condole with': 88138,
#  'Eucalyptus dumosa': 175025,
#  'arthroscope': 373,
#  'filander': 88145,
#  'object code': 175021,
#  'phonics': 376,
#  'interruptingly': 88150,
#  'monophthong': 379,
#  'Desiderius Erasmus': 88152,
#  'photo opportunity': 88153,
#  'fertilized': 381,
#  'clubrush': 88156,
#  'temporoparietalis muscle': 88157,
#  'unbloody': 2392,
#  'leaviness': 88158,
#  'campanulate': 11700,
#  'nyepi': 87658,
#  'anthropomorphosis': 175026,
#  'fortax': 88165,
#  'annabergite': 88166,
#  'oligopoly': 393,
#  'rice congee': 88172,
#  'spruce bark beetle': 88168,
#  'utah': 394,
#  'coruscations': 397,
#  'disprejudice': 88179,
#  'blimp': 398,
#  'Philip of Valois': 88181,
#  'genus Vesicaria': 88183,
#  'ncs': 400,
#  'hellbrewed': 88186,
#  'glossographer': 88187,
#  'deep blue sea': 88192,
#  'subthalamus': 19054,
#  'apex': 78894,
#  'levodopa': 88196,
#  'flags': 58193,
#  'hollywood': 406,
#  'quixotically': 339529,
#  'mailperson': 88198,
#  'augustinians': 56109,
#  'adelgid': 2557,
#  'adult male body': 88203,
#  'Gentiana crinita': 88204,
#  'dramatic production': 88205,
#  'throw a wobbly': 88206,
#  'storklike': 415,
#  'long-spurred violet': 88207,
#  'torpidity': 88211,
#  'interpolymer': 88212,
#  'transpassed': 58195,
#  'stemless golden weed': 262544,
#  'jenni': 87668,
#  'knees-up': 88214,
#  'nelumbo': 422,
#  'potato yellow dwarf': 88217,
#  'illegal number': 88219,
#  'lens of the eye': 88220,
#  'prohibit': 425,
#  'oysterfish': 88221,
#  'Ladrone Islands': 88222,
#  'Josephus': 88223,
#  'amendatory': 88225,
#  'ungalvanized': 88228,
#  'pristine': 429,
#  'reflame': 88232,
#  'amphimacer': 88231,
#  'votress': 88233,
#  'rhizopathy': 88234,
#  'make light of': 88237,
#  'machoness': 88236,
#  'batsmans': 29043,
#  'coregulation': 88245,
#  'amyoplasia': 88241,
#  'comedically': 88249,
#  'ethical motive': 88248,
#  'lab': 438,
#  'acquisitionally': 88252,
#  'eminences': 444,
#  'debruise': 88257,
#  'manifestolike': 88258,
#  'chepster': 88260,
#  'tallit': 88262,
#  'blamer': 88263,
#  'brown windsor soup': 88264,
#  'big businessman': 88265,
#  'Federal Democratic Republic of Ethiopia': 88273,
#  'sesspool': 88275,
#  'infangthef': 88276,
#  'grove snail': 88279,
#  'classs': 458,
#  'gruellingly': 88283,
#  'rate of depreciation': 88284,
#  'matter of course': 88285,
#  'coaching stock': 88289,
#  'snog': 465,
#  'retrigger': 88292,
#  'idiopathic hemochromatosis': 175045,
#  'occidentale': 467,
#  'Hygrophorus inocybiformis': 87680,
#  'well-travelled': 88298,
#  'Clematis ochreleuca': 88299,
#  'Valentine Day': 88300,
#  'polysulphide': 3415,
#  'studded': 473,
#  'flare out': 88306,
#  'erythrina': 474,
#  'free-for-all': 88310,
#  'moderatorship': 88311,
#  'turquoise': 476,
#  'Shreveport': 88312,
#  'rostov-na-donu': 88314,
#  'genus Crescentia': 88318,
#  'bird of paradise': 340270,
#  'gemsbok': 485,
#  'haligonian': 88321,
#  'reprobative': 88325,
#  'crush party': 88326,
#  'nominatival': 88327,
#  'genus Capreolus': 88328,
#  'contrapolar': 87689,
#  'endognath': 88331,
#  'optoisolator': 175058,
#  'seamlessly': 492,
#  'getterup': 87687,
#  'nonmagically': 88333,
#  'demeter': 500,
#  'pilosity': 175060,
#  'raft': 501,
#  'cogenerate': 88339,
#  'freedomless': 88341,
#  'leafage': 504,
#  'discount department store': 88342,
#  'Conyza canadensis': 88343,
#  'adrenalin rush': 88344,
#  'McGuffin': 88347,
#  'manuscripts': 509,
#  'sundial': 513,
#  'dolphin-friendly': 88354,
#  'fiduciary duty': 88356,
#  'watersoaked': 175068,
#  'Lowell Thomas': 88360,
#  'pinch-hit': 87700,
#  'cancer stick': 88361,
#  'pinkie': 523,
#  'payoff': 524,
#  'uterine contraction': 88366,
#  'tax shelter': 88368,
#  'postman': 3225,
#  'lichenography': 530,
#  'marx': 531,
#  'memory': 533,
#  'velvety-furred': 88371,
#  'demisharp': 88373,
#  'pacific newt': 88374,
#  'enemy': 536,
#  'jelutong': 88376,
#  'phylogeny': 537,
#  'back bacon': 88379,
#  'lender': 540,
#  'nonvictimized': 88381,
#  'seedlip': 88383,
#  'triatome': 88388,
#  'lansquenet': 88386,
#  'European nuthatch': 88387,
#  'pizzas': 542,
#  'mis-sell': 88390,
#  'befeather': 88392,
#  'forgo': 16188,
#  'cut-up': 88395,
#  'Mayenne': 88396,
#  'unostentatious': 551,
#  'phosphazine': 88399,
#  'Ulmus hollandica': 88400,
#  'virginia': 554,
#  'nineteen twenty-six': 88401,
#  'overindebtedness': 88403,
#  'refrigerate': 560,
#  'Ulmus thomasii': 88406,
#  'diesel-electric': 88408,
#  'antichrist': 567,
#  'humectation': 88414,
#  'merchandisable': 88413,
#  'qallunaaq': 88415,
#  'proposes': 3423,
#  'sickness': 572,
#  'cinnamony': 88420,
#  'bullaris': 577,
#  'computer error': 88422,
#  'officinalis': 578,
#  'gray sage': 88426,
#  'congenital disorder': 88427,
#  'doodia': 3486,
#  'rizal': 580,
#  'airedale': 88429,
#  'theatre ticket': 88430,
#  'indignance': 88431,
#  'little-league team': 262577,
#  'alto-relievo': 88436,
#  'showoff': 588,
#  'thaught': 88437,
#  'tantalum': 590,
#  'poke check': 87709,
#  'periscope': 592,
#  'limbic brain': 88439,
#  'hispanism': 88441,
#  'litharge': 595,
#  'exhilarated': 3589,
#  'greensand': 606,
#  'polytheistically': 88452,
#  'florida anise': 88451,
#  'varisse': 88457,
#  'fewly': 88459,
#  'quantum chemistry': 88462,
#  'greyblack': 609,
#  'reheated': 83657,
#  'steamers': 72326,
#  'sea cole': 88468,
#  'zinc cadmium sulfide': 88470,
#  'anthropomorphization': 88471,
#  'balloonlike': 88472,
#  'ingenuous': 612,
#  'warfarer': 88474,
#  'peg warmer': 88475,
#  'micromillimetre': 262584,
#  'panduriform leaf': 88477,
#  'convenable': 88479,
#  'sarraceniales': 3736,
#  'white dwarf': 88480,
#  'amine ylide': 88484,
#  'sexvalent': 88485,
#  'parrotry': 88487,
#  're-collect': 88490,
#  'cauterized': 3773,
#  'hyperbaton': 88491,
#  'Lebistes reticulatus': 88493,
#  'dolcelatte': 87718,
#  'tanglebush': 88498,
#  'secondguess': 40539,
#  'fearful': 632,
#  'cricoid': 633,
#  'Harrisia': 88500,
#  'enantiomerically': 88503,
#  'under sail': 88507,
#  'confusing': 636,
#  'tardily': 638,
#  'unhesitating': 640,
#  'Mycenaean civilization': 88511,
#  'lupine': 641,
#  'akinetic epilepsy': 88513,
#  'nutate': 88515,
#  'viomycin': 88516,
#  'gloze': 88519,
#  'bioengineering': 645,
#  'colorimetrical': 88521,
#  'olympics': 646,
#  'homology': 73806,
#  'chiropractic': 649,
#  'california': 29072,
#  'photobleach': 88526,
#  'palliates': 653,
#  'ravenously': 19211,
#  'acridology': 88532,
#  'intragastrically': 88535,
#  'argyrol': 657,
#  'chicory escarole': 88536,
#  'nobility': 658,
#  'hypoiodous acid': 88538,
#  'languor': 661,
#  'drapes': 662,
#  'outlick': 88544,
#  'palaeosol': 88546,
#  'coenzyme ii': 88547,
#  'unlade': 667,
#  'manacled': 74489,
#  'late-flowering': 88551,
#  'litterless': 88555,
#  'wendell': 30782,
#  'ten percent': 88559,
#  'California wine': 88563,
#  'transaction file': 175089,
#  'blackish': 680,
#  'puddles': 681,
#  'bereavement': 682,
#  'genus Fistulina': 88568,
#  'Cypripedium reginae': 88571,
#  'like feeding time at the zoo': 88573,
#  'accelerator factor': 88574,
#  'Lilium auratum': 88576,
#  'popes': 690,
#  'perineoplasty': 88579,
#  'glycoform': 88580,
#  'pictorial representation': 88581,
#  'aires': 693,
#  'deathmatch': 694,
#  'genus Ixia': 88584,
#  'circumagitate': 88585,
#  'chitin': 695,
#  'insalutary': 88588,
#  'unprison': 262602,
#  'gerstleyite': 87736,
#  'lipitor': 698,
#  'scabby': 58245,
#  'paper tiger': 88592,
#  'Pompeii': 88593,
#  'support payment': 88596,
#  'Dryopithecus Rudapithecus hungaricus': 88597,
#  'down quark': 88601,
#  'devkit': 175096,
#  'circling': 705,
#  'electrodeposition': 708,
#  'hydroximic': 88607,
#  'conflated': 4233,
#  'astronomical unit': 88608,
#  'indocible': 88615,
#  'befriender': 88610,
#  'ultima Thule': 88612,
#  'grummet': 88614,
#  'vista': 714,
#  'camgasite': 88619,
#  'octupole': 29080,
#  'Monotropa uniflora': 88622,
#  'smoke bomb': 87741,
#  'buenos': 719,
#  'concretional': 87743,
#  'ramose': 262606,
#  'wherever you go, there you are': 88630,
#  'gallocatechol': 724,
#  'guiltlike': 88631,
#  'star begonia': 88632,
#  'opsonins': 4329,
#  'nonparthenogenetic': 88634,
#  'nonassignment': 88636,
#  'declamation': 125,
#  'have the blues': 88637,
#  'birdwatchers': 731,
#  'subfamily Melolonthidae': 88640,
#  'keix': 732,
#  'glucomannan': 88644,
#  'chaidario': 88645,
#  'polysyllabicism': 88652,
#  'fub': 88647,
#  'stagnates': 85763,
#  'genipap': 88655,
#  'phylum Cycliophora': 88656,
#  'common roundworm': 88659,
#  'acault': 88660,
#  'extra-miler': 88663,
#  'gaming': 742,
#  'uptime': 88664,
#  'pollinic': 88667,
#  'uncomplete': 88668,
#  'notary': 743,
#  'cardiorenal': 88671,
#  'Cameroon': 88674,
#  'bounded function': 88675,
#  'campinas': 88676,
#  'facial vein': 88677,
#  'gang of four': 88678,
#  'befuddlement': 88679,
#  'chaos theory': 88683,
#  'unexhausted': 759,
#  'acrogynous': 88685,
#  'gung ho': 88686,
#  'King of France': 88689,
#  'vulgarizer': 88690,
#  'family Asphodelaceae': 88692,
#  'forhend': 88696,
#  'asarone': 88694,
#  'minutelytoothed': 769,
#  'into thin air': 88700,
#  'undisciplined': 133,
#  'reconsenting': 316184,
#  'uncentered': 88705,
#  'pull a fast one on': 88706,
#  'o.m.': 257068,
#  'Verrazzano': 88708,
#  'nonphagocytic': 88709,
#  'barcoded': 88711,
#  'creeping Jenny': 88713,
#  'ultracapable': 88714,
#  'funereal': 782,
#  'nematocalyces': 88718,
#  'palapteryx': 88719,
#  'meathe': 1441,
#  'tegumentary': 88729,
#  'white broom': 88723,
#  'intermediate vector boson': 262624,
#  'negotiosity': 88726,
#  'epiclinal': 88728,
#  'postencephalon': 88731,
#  'draggled': 87756,
#  'omega-3 fatty acid': 175113,
#  'personal social health education': 88732,
#  'debaptism': 87758,
#  'sensuous': 793,
#  'Anglican': 88733,
#  'agee': 4738,
#  'irefulness': 87760,
#  'coy': 803,
#  'noninterrogative': 88740,
#  'fitz-': 262630,
#  'genus Cordaites': 88742,
#  'transvestite': 56514,
#  'foreside': 88744,
#  'mustee': 88746,
#  'longleaf': 810,
#  'waisted': 88747,
#  'jiujitsu': 88749,
#  'Eriophyllum': 88751,
#  'bank shot': 88752,
#  'Ceroxylon alpinum': 88754,
#  'kurchi': 333111,
#  'GB': 88755,
#  'translatorship': 88757,
#  'cream cheese': 88758,
#  'wipe': 825,
#  'ekspreso': 88759,
#  'third party': 88761,
#  'golden thread': 88762,
#  'disproportionable': 827,
#  'nounless': 88763,
#  'amrinone': 88764,
#  'wicklike': 88765,
#  'glossitis': 831,
#  'scatter rug': 88766,
#  'berretta': 88767,
#  'pot': 834,
#  'cuttable': 88769,
#  'wipe the slate clean': 88775,
#  'schoolmasterly': 88774,
#  'darc': 3547,
#  'heart-rending': 88777,
#  'dispatch case': 88781,
#  'decontrol': 88783,
#  'hooyah': 88784,
#  'distrainor': 88786,
#  'bobble': 848,
#  'leatherjack': 88787,
#  'homeotic': 147,
#  'bonjour': 88793,
#  'deathtime': 88794,
#  'flight simulator': 88795,
#  'arteria testicularis': 88796,
#  'peskily': 88799,
#  'quasiparticle': 853,
#  'mastax': 856,
#  'necessity is the mother of invention': 88802,
#  'willfully': 5038,
#  'ash-pan': 88806,
#  'family Solenidae': 88809,
#  'karahi': 88810,
#  'pillow case': 175127,
#  'saanich': 87777,
#  'multi-level marketing': 88814,
#  'bear paw': 316282,
#  'housed': 868,
#  'picture window': 88817,
#  'drink problem': 88820,
#  'victorias': 871,
#  'cefotaximase': 88827,
#  'middle cerebral vein': 262642,
#  'denaina': 87773,
#  'traveltime': 88828,
#  'Isfahan': 88829,
#  'coasteering': 88835,
#  'mung bean': 88830,
#  'cybernews': 88838,
#  'World War 2': 262643,
#  'isoamyl nitrite': 88836,
#  'discovering': 880,
#  'angel cake': 262644,
#  'game law': 88841,
#  'commotion': 887,
#  'dependents': 889,
#  'mastic tree': 88846,
#  'underlying form': 88847,
#  'hymn': 58277,
#  'knobtwat': 88849,
#  'Silene vulgaris': 262648,
#  'short aria': 88850,
#  'tech': 905,
#  'lua': 88859,
#  'bulletin': 5279,
#  'mycroft holmes': 88865,
#  'tristigmatose': 88869,
#  'cladistic': 915,
#  'reet canny': 88874,
#  'obolus': 88877,
#  'nutter': 88878,
#  'ethiopian wolf': 88883,
#  'Lampropeltis triangulum': 88886,
#  'primitive art': 88887,
#  'blazoning': 922,
#  'immunogeneticist': 88888,
#  'quest': 924,
#  'F region': 88890,
#  'homoaromacity': 88892,
#  'unnethe': 88893,
#  'dangle': 925,
#  'cloistral': 926,
#  'fucknut': 88896,
#  'hypofusion': 88899,
#  'alveary': 88897,
#  'marvel-of-Peru': 88900,
#  'basketball season': 88901,
#  'work someones tail off': 88905,
#  'pedalian': 88903,
#  'polylithionite': 87792,
#  'lege': 88906,
#  'noncarnival': 87790,
#  'edge out': 88909,
#  'chromium-52': 88910,
#  'double acrostic': 88912,
#  'reedwork': 29119,
#  'chinese pangolin': 88918,
#  'low-cost': 88917,
#  'trail riding': 88919,
#  'go large': 88922,
#  'johannesburg': 943,
#  'redintegration': 88926,
#  'flysch': 88927,
#  'porterhouse steak': 88928,
#  'small talk': 88930,
#  'abolishing': 949,
#  'Latin America': 88931,
#  'Nevelson': 88934,
#  'resolvere': 951,
#  'procurement': 953,
#  'rocket fuel': 88937,
#  'chalk out': 88938,
#  'Araujia': 88939,
#  'sherlockian': 88942,
#  'keynesian': 959,
#  'eisenia': 58294,
#  'phiran': 88944,
#  'walrasian': 88945,
#  'mealiness': 88947,
#  'phosphatrane': 88948,
#  'indras': 963,
#  'salvager': 88949,
#  'regard': 966,
#  'Texas': 88953,
#  'meaninglessness': 29122,
#  'adduring': 968,
#  'photogenically': 262660,
#  'sixrayed': 970,
#  'smogginess': 88958,
#  'law of diminishing returns': 88959,
#  'iniopterygian': 88960,
#  'redemption game': 175148,
#  'Crotalus viridis': 88962,
#  'podosome': 88964,
#  'lahmu': 88965,
#  'bengal': 58297,
#  'yellow locust': 88967,
#  'depredated': 981,
#  'hapten': 982,
#  'interjectionally': 88972,
#  'narcotrafficker': 88971,
#  'block and tackle': 262661,
#  'canting': 17452,
#  'coadsorbed': 88976,
#  'brisk': 984,
#  'genus Carpenteria': 88977,
#  'rotresistant': 72269,
#  'nominee': 987,
#  'Jahweh': 88982,
#  'demotivation': 87800,
#  'cuckquean': 88989,
#  'pupas': 993,
#  'uncategorizably': 88994,
#  'slopping': 5752,
#  'disordination': 88996,
#  'orthotetrahedron': 88997,
#  'traffic control': 88998,
#  'betise': 89000,
#  'rand': 5773,
#  'tongo': 262667,
#  'mahabarata': 89007,
#  'bacteriotherapy': 89005,
#  'linear-shaped': 89008,
#  'annuli': 89010,
#  'technologyless': 89014,
#  'forwardprojecting': 1009,
#  'incy wincy': 89016,
#  'niteosaccharin': 89018,
#  'sandlike': 1012,
#  'esophageal cancer': 89023,
#  'Prunus persica nectarina': 89022,
#  'throated': 5851,
#  'scribblement': 89027,
#  'recombinant protein': 186853,
#  'nucleolytic': 89029,
#  'accretions': 13933,
#  'Phrynosoma cornutum': 89031,
#  'hunt saboteur': 89033,
#  'hodiernal': 89034,
#  'fithul': 175160,
#  'Andre Paul Guillaume Gide': 89036,
#  'on purpose': 262674,
#  'sincerus': 1019,
#  'aluminum industry': 89037,
#  'Tasmania': 89040,
#  'minds eye': 89042,
#  'grande wormwood': 89045,
#  'disturbance regime': 89046,
#  'ovariotomy': 89047,
#  'phosphoinositide': 89048,
#  'overtake': 1026,
#  'genus Polyprion': 175165,
#  'relational database': 89051,
#  'latterkin': 89053,
#  'garden cart': 89056,
#  'outrun': 1035,
#  'balsam pear': 89060,
#  'electroceramic': 89062,
#  'iron-gray': 262678,
#  'polythionic acid': 89067,
#  'bride-ale': 327406,
#  'genus Cucumis': 89068,
#  'genus Gladiolus': 89069,
#  'adventureless': 89071,
#  'family Dugongidae': 89073,
#  'detention house': 89075,
#  'woylie': 107973,
#  'cybersabotage': 89077,
#  'inhabiter': 89078,
#  'step to the fore': 89079,
#  'drabcloth': 87811,
#  'Fucus serratus': 89081,
#  'relation back': 262684,
#  'postfix': 1053,
#  'leucotome': 89084,
#  'bec de corbin': 89085,
#  'animalic': 262683,
#  'bakery': 1056,
#  'worstly': 89087,
#  'brambles': 1057,
#  'demiss': 89088,
#  'divagation': 89089,
#  'double-magnum': 89090,
#  ...}
